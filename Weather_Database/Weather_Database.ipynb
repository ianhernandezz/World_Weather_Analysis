# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 599

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Current Description": city_weather_description,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Country": city_country,
                             "Date": city_date})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | geraldton
# Processing Record 3 of Set 1 | kodiak
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | los llanos de aridane
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | grand gaube
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | bluff
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | busselton
# Processing Record 21 of Set 1 | grindavik
# Processing Record 23 of Set 1 | husavik
# Processing Record 25 of Set 1 | turochak
# Processing Record 27 of Set 1 | albany
# Processing Record 29 of Set 1 | narsaq
# Processing Record 31 of Set 1 | tecoanapa
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | tiksi
# Processing Record 37 of Set 1 | stokmarknes
# Processing Record 39 of Set 1 | barcelona
# Processing Record 41 of Set 1 | khatanga
# Processing Record 43 of Set 1 | guerrero negro
# Processing Record 45 of Set 1 | souillac
# Processing Record 47 of Set 1 | butaritari
# Processing Record 49 of Set 1 | mildura
# Processing Record 51 of Set 1 | maxixe
# Processing Record 53 of Set 1 | bredasdorp
# Processing Record 55 of Set 1 | vostok
# Processing Record 57 of Set 1 | balimo
# City not found. Skipping...
# Processing Record 59 of Set 1 | sao raimundo nonato
# Processing Record 61 of Set 1 | atambua
# Processing Record 63 of Set 1 | norman wells
# Processing Record 65 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 67 of Set 1 | jamestown
# Processing Record 69 of Set 1 | port alfred
# Processing Record 71 of Set 1 | harper
# Processing Record 73 of Set 1 | areosa
# Processing Record 75 of Set 1 | kruisfontein
# Processing Record 77 of Set 1 | tabou
# Processing Record 79 of Set 1 | leningradskiy
# Processing Record 81 of Set 1 | palmer
# Processing Record 83 of Set 1 | parabel
# Processing Record 85 of Set 1 | yeppoon
# Processing Record 87 of Set 1 | rikitea
# Processing Record 89 of Set 1 | cabo san lucas
# Processing Record 91 of Set 1 | hilo
# Processing Record 93 of Set 1 | yar-sale
# Processing Record 95 of Set 1 | hasaki
# Processing Record 97 of Set 1 | avarua
# Processing Record 99 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | auki
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | westport
# Processing Record 7 of Set 2 | novyy urengoy
# Processing Record 9 of Set 2 | haines junction
# Processing Record 11 of Set 2 | lerwick
# Processing Record 13 of Set 2 | gbarnga
# Processing Record 15 of Set 2 | hirara
# Processing Record 17 of Set 2 | iraucuba
# Processing Record 19 of Set 2 | chuy
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | shenjiamen
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 27 of Set 2 | sirnak
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | gjusvik
# City not found. Skipping...
# Processing Record 33 of Set 2 | vasterhaninge
# Processing Record 35 of Set 2 | tezu
# Processing Record 37 of Set 2 | cape town
# Processing Record 39 of Set 2 | zhangjiakou
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | abu samrah
# Processing Record 45 of Set 2 | atuona
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 2 | hobart
# Processing Record 51 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 53 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 55 of Set 2 | thompson
# Processing Record 57 of Set 2 | kapaa
# Processing Record 59 of Set 2 | exeter
# Processing Record 61 of Set 2 | carquefou
# Processing Record 63 of Set 2 | sovetskiy
# Processing Record 65 of Set 2 | hamilton
# Processing Record 67 of Set 2 | mataura
# Processing Record 69 of Set 2 | port hardy
# Processing Record 71 of Set 2 | naze
# Processing Record 73 of Set 2 | lorengau
# Processing Record 75 of Set 2 | vaini
# Processing Record 77 of Set 2 | yerbogachen
# Processing Record 79 of Set 2 | balikpapan
# Processing Record 81 of Set 2 | barrow
# Processing Record 83 of Set 2 | port blair
# Processing Record 85 of Set 2 | vestmannaeyjar
# Processing Record 87 of Set 2 | tanete
# Processing Record 89 of Set 2 | severnyy
# Processing Record 91 of Set 2 | ribeira grande
# Processing Record 93 of Set 2 | tambura
# Processing Record 95 of Set 2 | mayskiy
# Processing Record 97 of Set 2 | tessalit
# Processing Record 99 of Set 2 | alice springs
# Processing Record 1 of Set 3 | chickasha
# Processing Record 3 of Set 3 | east london
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | taoudenni
# Processing Record 9 of Set 3 | aklavik
# Processing Record 11 of Set 3 | ngama
# Processing Record 13 of Set 3 | bontang
# Processing Record 15 of Set 3 | kavieng
# Processing Record 17 of Set 3 | ilanskiy
# Processing Record 19 of Set 3 | itaquyry
# Processing Record 21 of Set 3 | salta
# Processing Record 23 of Set 3 | itoman
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | kavaratti
# Processing Record 29 of Set 3 | road town
# Processing Record 31 of Set 3 | beloha
# Processing Record 33 of Set 3 | camopi
# Processing Record 35 of Set 3 | provideniya
# Processing Record 37 of Set 3 | hermanus
# Processing Record 39 of Set 3 | vardo
# Processing Record 41 of Set 3 | constitucion
# Processing Record 43 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | victoria
# Processing Record 47 of Set 3 | bereznik
# Processing Record 49 of Set 3 | motygino
# Processing Record 51 of Set 3 | nome
# Processing Record 53 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 55 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 57 of Set 3 | bandarbeyla
# Processing Record 59 of Set 3 | pittsburg
# Processing Record 61 of Set 3 | maarianhamina
# Processing Record 63 of Set 3 | punta arenas
# Processing Record 65 of Set 3 | kununurra
# Processing Record 67 of Set 3 | brownsville
# Processing Record 69 of Set 3 | tarare
# Processing Record 71 of Set 3 | saint anthony
# Processing Record 73 of Set 3 | ponta do sol
# Processing Record 75 of Set 3 | chokurdakh
# Processing Record 77 of Set 3 | santa rosa
# Processing Record 79 of Set 3 | mahebourg
# Processing Record 81 of Set 3 | saint george
# Processing Record 83 of Set 3 | highlands ranch
# Processing Record 85 of Set 3 | ancud
# Processing Record 87 of Set 3 | itarema
# Processing Record 89 of Set 3 | phonhong
# Processing Record 91 of Set 3 | khani
# Processing Record 93 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 95 of Set 3 | papetoai
# Processing Record 97 of Set 3 | pavlodar
# Processing Record 99 of Set 3 | lahaina
# Processing Record 1 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | clyde river
# Processing Record 5 of Set 4 | castro
# Processing Record 7 of Set 4 | tornio
# Processing Record 9 of Set 4 | walvis bay
# Processing Record 11 of Set 4 | lakes entrance
# Processing Record 13 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 4 | urucara
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | wonthaggi
# Processing Record 23 of Set 4 | airai
# Processing Record 25 of Set 4 | ledyard
# Processing Record 27 of Set 4 | marsa matruh
# Processing Record 29 of Set 4 | roma
# Processing Record 31 of Set 4 | winnemucca
# Processing Record 33 of Set 4 | cidreira
# Processing Record 35 of Set 4 | zihuatanejo
# Processing Record 37 of Set 4 | tura
# Processing Record 39 of Set 4 | srednekolymsk
# Processing Record 41 of Set 4 | saldanha
# Processing Record 43 of Set 4 | ilulissat
# Processing Record 45 of Set 4 | nakhon luang
# Processing Record 47 of Set 4 | baie-comeau
# Processing Record 49 of Set 4 | dawlatabad
# Processing Record 51 of Set 4 | krasnoborsk
# Processing Record 53 of Set 4 | vao
# Processing Record 55 of Set 4 | anchorage
# Processing Record 57 of Set 4 | upernavik
# Processing Record 59 of Set 4 | soyo
# Processing Record 61 of Set 4 | laguna
# Processing Record 63 of Set 4 | iqaluit
# Processing Record 65 of Set 4 | kaitangata
# Processing Record 67 of Set 4 | antipovka
# Processing Record 69 of Set 4 | arraial do cabo
# Processing Record 71 of Set 4 | matamoros
# Processing Record 73 of Set 4 | nelson bay
# Processing Record 75 of Set 4 | padang
# Processing Record 77 of Set 4 | te anau
# Processing Record 79 of Set 4 | diffa
# Processing Record 81 of Set 4 | buraydah
# Processing Record 83 of Set 4 | college
# Processing Record 85 of Set 4 | tuim
# Processing Record 87 of Set 4 | esperance
# Processing Record 89 of Set 4 | imeni poliny osipenko
# Processing Record 91 of Set 4 | sabang
# Processing Record 93 of Set 4 | amberley
# Processing Record 95 of Set 4 | sitka
# Processing Record 97 of Set 4 | orlik
# Processing Record 99 of Set 4 | khandyga
# Processing Record 1 of Set 5 | mahon
# Processing Record 3 of Set 5 | lasa
# Processing Record 5 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 5 | vila franca do campo
# Processing Record 9 of Set 5 | pilar
# Processing Record 11 of Set 5 | luang prabang
# Processing Record 13 of Set 5 | bowen
# Processing Record 15 of Set 5 | vila
# Processing Record 17 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | seoul
# Processing Record 21 of Set 5 | ketchikan
# Processing Record 23 of Set 5 | kalmunai
# Processing Record 25 of Set 5 | pemangkat
# Processing Record 27 of Set 5 | dzhebariki-khaya
# Processing Record 29 of Set 5 | hofn
# Processing Record 31 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 35 of Set 5 | tuxtepec
# Processing Record 37 of Set 5 | wewak
# Processing Record 39 of Set 5 | dikson
# Processing Record 41 of Set 5 | mut
# Processing Record 43 of Set 5 | camana
# Processing Record 45 of Set 5 | kysyl-syr
# Processing Record 47 of Set 5 | tieli
# Processing Record 49 of Set 5 | neiafu
# Processing Record 51 of Set 5 | klaksvik
# Processing Record 53 of Set 5 | morro bay
# Processing Record 55 of Set 5 | chernyshevskiy
# Processing Record 57 of Set 5 | ahipara
# Processing Record 59 of Set 5 | cherskiy
# Processing Record 61 of Set 5 | hualmay
# Processing Record 63 of Set 5 | tuatapere
# Processing Record 65 of Set 5 | tiarei
# Processing Record 67 of Set 5 | tashigang
# Processing Record 69 of Set 5 | mayo
# Processing Record 71 of Set 5 | dingle
# Processing Record 73 of Set 5 | codrington
# Processing Record 75 of Set 5 | poum
# Processing Record 77 of Set 5 | kabanjahe
# Processing Record 79 of Set 5 | pointe michel
# Processing Record 81 of Set 5 | tadine
# Processing Record 83 of Set 5 | grahamstown
# Processing Record 85 of Set 5 | eastbourne
# Processing Record 87 of Set 5 | bethel
# Processing Record 89 of Set 5 | flin flon
# Processing Record 91 of Set 5 | hanzhong
# Processing Record 93 of Set 5 | dunedin
# Processing Record 95 of Set 5 | kristinehamn
# Processing Record 97 of Set 5 | sioux lookout
# Processing Record 99 of Set 5 | tasiilaq
# Processing Record 1 of Set 6 | bhiwani
# Processing Record 3 of Set 6 | lamu
# Processing Record 5 of Set 6 | olinda
# Processing Record 7 of Set 6 | zhireken
# Processing Record 9 of Set 6 | safford
# Processing Record 11 of Set 6 | opuwo
# Processing Record 13 of Set 6 | torbay
# Processing Record 15 of Set 6 | okhotsk
# Processing Record 17 of Set 6 | san policarpo
# Processing Record 19 of Set 6 | saint-augustin
# Processing Record 21 of Set 6 | champerico
# Processing Record 23 of Set 6 | sisimiut
# Processing Record 25 of Set 6 | morondava
# Processing Record 27 of Set 6 | altay
# Processing Record 29 of Set 6 | norrtalje
# Processing Record 31 of Set 6 | agadez
# Processing Record 33 of Set 6 | saint-philippe
# Processing Record 35 of Set 6 | luderitz
# Processing Record 37 of Set 6 | carnarvon
# Processing Record 39 of Set 6 | ponta delgada
# Processing Record 41 of Set 6 | juneau
# Processing Record 43 of Set 6 | panzhihua
# Processing Record 45 of Set 6 | fethiye
# Processing Record 47 of Set 6 | mokhotlong
# Processing Record 49 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 51 of Set 6 | katubao
# Processing Record 53 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 55 of Set 6 | salym
# Processing Record 57 of Set 6 | saint-pierre
# Processing Record 59 of Set 6 | georgetown
# Processing Record 61 of Set 6 | cerro de pasco
# Processing Record 63 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 65 of Set 6 | nosy varika
# Processing Record 67 of Set 6 | ozernovskiy
# Processing Record 69 of Set 6 | halifax
# Processing Record 71 of Set 6 | brookhaven
# Processing Record 73 of Set 6 | meulaboh
# Processing Record 75 of Set 6 | katsuura
# Processing Record 77 of Set 6 | chaman
# Processing Record 79 of Set 6 | camasca
# Processing Record 81 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 83 of Set 6 | pisco
# Processing Record 85 of Set 6 | rio gallegos
# Processing Record 87 of Set 6 | san quintin
# Processing Record 89 of Set 6 | huarmey
# Processing Record 91 of Set 6 | nizhnevartovsk
# Processing Record 93 of Set 6 | edd
# Processing Record 95 of Set 6 | salalah
# Processing Record 97 of Set 6 | port elizabeth
# Processing Record 99 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 7 | angoche
# Processing Record 3 of Set 7 | klyuchi
# Processing Record 5 of Set 7 | finschhafen
# Processing Record 7 of Set 7 | noumea
# Processing Record 9 of Set 7 | alofi
# Processing Record 11 of Set 7 | zhaotong
# Processing Record 13 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 15 of Set 7 | mount gambier
# Processing Record 17 of Set 7 | monroe
# Processing Record 19 of Set 7 | kirensk
# Processing Record 21 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 7 | merrill
# Processing Record 25 of Set 7 | kieta
# Processing Record 27 of Set 7 | svetlogorsk
# Processing Record 29 of Set 7 | roebourne
# Processing Record 31 of Set 7 | kiama
# Processing Record 33 of Set 7 | tilichiki
# Processing Record 35 of Set 7 | balkanabat
# Processing Record 37 of Set 7 | douentza
# Processing Record 39 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 41 of Set 7 | akyab
# Processing Record 43 of Set 7 | ngunguru
# Processing Record 45 of Set 7 | katherine
# Processing Record 47 of Set 7 | sampit
# Processing Record 49 of Set 7 | kaa-khem
# Processing Record 51 of Set 7 | alot
# Processing Record 53 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 55 of Set 7 | mount darwin
# Processing Record 57 of Set 7 | nouadhibou
# Processing Record 59 of Set 7 | toropets
# Processing Record 61 of Set 7 | santa maria
# Processing Record 63 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 65 of Set 7 | chifeng
# Processing Record 67 of Set 7 | buarcos
# Processing Record 69 of Set 7 | santiago
# Processing Record 71 of Set 7 | correntina
# Processing Record 73 of Set 7 | margate
# Processing Record 75 of Set 7 | marawi
# Processing Record 77 of Set 7 | myitkyina
# Processing Record 79 of Set 7 | sharjah
# Processing Record 81 of Set 7 | makakilo city
# Processing Record 83 of Set 7 | ondangwa
# Processing Record 85 of Set 7 | viedma
# Processing Record 87 of Set 7 | robertsport
# Processing Record 89 of Set 7 | melilla
# Processing Record 91 of Set 7 | nabire
# Processing Record 93 of Set 7 | bireun
# Processing Record 95 of Set 7 | karpogory
# Processing Record 97 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 99 of Set 7 | dzialdowo
# Processing Record 1 of Set 8 | yulara
# Processing Record 3 of Set 8 | myrtle beach
# Processing Record 5 of Set 8 | merauke
# Processing Record 7 of Set 8 | jalu
# Processing Record 9 of Set 8 | biak
# Processing Record 11 of Set 8 | yumen
# Processing Record 13 of Set 8 | pundaguitan
# Processing Record 15 of Set 8 | arroio dos ratos
# Processing Record 17 of Set 8 | fortuna
# Processing Record 19 of Set 8 | reconquista
# Processing Record 21 of Set 8 | revda
# Processing Record 23 of Set 8 | verkh-usugli
# Processing Record 25 of Set 8 | pochutla
# Processing Record 27 of Set 8 | kismayo
# Processing Record 29 of Set 8 | san patricio
# Processing Record 31 of Set 8 | alexandria
# Processing Record 33 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | bouar
# Processing Record 37 of Set 8 | mandvi
# Processing Record 39 of Set 8 | awjilah
# Processing Record 41 of Set 8 | severo-kurilsk
# Processing Record 43 of Set 8 | kloulklubed
# Processing Record 45 of Set 8 | desbiens
# Processing Record 47 of Set 8 | sivaki
# Processing Record 49 of Set 8 | villa carlos paz
# Processing Record 51 of Set 8 | boali
# Processing Record 53 of Set 8 | nanortalik
# Processing Record 55 of Set 8 | copalau
# Processing Record 57 of Set 8 | kinna
# Processing Record 59 of Set 8 | port-gentil
# Processing Record 61 of Set 8 | kurgan
# Processing Record 63 of Set 8 | sawtell
# Processing Record 65 of Set 8 | fremont
# Processing Record 67 of Set 8 | vanavara
# Processing Record 69 of Set 8 | athabasca
# Processing Record 71 of Set 8 | talladega
# Processing Record 73 of Set 8 | great falls
# Processing Record 75 of Set 8 | havre-saint-pierre
# Processing Record 77 of Set 8 | kousseri
# Processing Record 79 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 81 of Set 8 | yuci
# Processing Record 83 of Set 8 | la rioja
# Processing Record 85 of Set 8 | baykit
# Processing Record 87 of Set 8 | revelstoke
# Processing Record 89 of Set 8 | ust-koksa
# Processing Record 91 of Set 8 | goba
# Processing Record 93 of Set 8 | dargaville
# Processing Record 95 of Set 8 | kahului
# Processing Record 97 of Set 8 | tubmanburg
# Processing Record 99 of Set 8 | griffith
# Processing Record 1 of Set 9 | pangnirtung
# Processing Record 3 of Set 9 | xocali
# Processing Record 5 of Set 9 | itacoatiara
# Processing Record 7 of Set 9 | gardan diwal
# City not found. Skipping...
# Processing Record 9 of Set 9 | broken hill
# Processing Record 11 of Set 9 | pevek
# Processing Record 13 of Set 9 | ayagoz
# Processing Record 15 of Set 9 | lake city
# Processing Record 17 of Set 9 | kenai
# Processing Record 19 of Set 9 | avera
# Processing Record 21 of Set 9 | nador
# Processing Record 23 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 25 of Set 9 | vilhena
# Processing Record 27 of Set 9 | plyussa
# Processing Record 29 of Set 9 | paamiut
# Processing Record 31 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 9 | hobyo
# Processing Record 35 of Set 9 | tandil
# Processing Record 37 of Set 9 | delta del tigre
# Processing Record 39 of Set 9 | verdun
# Processing Record 41 of Set 9 | povazska bystrica
# Processing Record 43 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 45 of Set 9 | chalinze
# Processing Record 47 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 9 | aba
# Processing Record 51 of Set 9 | waddan
# Processing Record 53 of Set 9 | ishinomaki
# Processing Record 55 of Set 9 | lebu
# Processing Record 57 of Set 9 | san pedro
# Processing Record 59 of Set 9 | vila do maio
# Processing Record 61 of Set 9 | aguimes
# Processing Record 63 of Set 9 | vilyuysk
# Processing Record 65 of Set 9 | skelleftea
# Processing Record 67 of Set 9 | shenzhen
# Processing Record 69 of Set 9 | rawson
# Processing Record 71 of Set 9 | giyani
# Processing Record 73 of Set 9 | yuncheng
# Processing Record 75 of Set 9 | oktyabrskiy
# Processing Record 77 of Set 9 | caibarien
# Processing Record 79 of Set 9 | faya
# Processing Record 81 of Set 9 | andra
# Processing Record 83 of Set 9 | koregaon
# Processing Record 85 of Set 9 | cockburn town
# Processing Record 87 of Set 9 | prince albert
# Processing Record 89 of Set 9 | slave lake
# Processing Record 91 of Set 9 | perth
# Processing Record 93 of Set 9 | lompoc
# Processing Record 95 of Set 9 | yakeshi
# Processing Record 97 of Set 9 | lata
# Processing Record 99 of Set 9 | sambava
# Processing Record 1 of Set 10 | ixtapa
# Processing Record 3 of Set 10 | chengde
# Processing Record 5 of Set 10 | kyaikto
# Processing Record 7 of Set 10 | sukhobezvodnoye
# Processing Record 9 of Set 10 | rabo de peixe
# Processing Record 11 of Set 10 | odessa
# Processing Record 13 of Set 10 | adrar
# Processing Record 15 of Set 10 | komsomolskiy
# Processing Record 17 of Set 10 | bom jesus da lapa
# Processing Record 19 of Set 10 | olden
# Processing Record 21 of Set 10 | coihaique
# Processing Record 23 of Set 10 | hit
# Processing Record 25 of Set 10 | roudnice
# Processing Record 27 of Set 10 | lastoursville
# Processing Record 29 of Set 10 | richards bay
# Processing Record 31 of Set 10 | itacarambi
# Processing Record 33 of Set 10 | maceio
# Processing Record 35 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 37 of Set 10 | oussouye
# Processing Record 39 of Set 10 | henties bay
# Processing Record 41 of Set 10 | sinnamary
# Processing Record 43 of Set 10 | ambovombe
# Processing Record 45 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 10 | sydney mines
# Processing Record 49 of Set 10 | labuhan
# Processing Record 51 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 53 of Set 10 | porosozero
# Processing Record 55 of Set 10 | sur
# Processing Record 57 of Set 10 | trincomalee
# Processing Record 59 of Set 10 | tahta
# Processing Record 61 of Set 10 | oga
# Processing Record 63 of Set 10 | saint-joseph
# Processing Record 65 of Set 10 | tobe
# Processing Record 67 of Set 10 | grafton
# Processing Record 69 of Set 10 | natal
# Processing Record 71 of Set 10 | nakamura
# Processing Record 73 of Set 10 | pandan
# Processing Record 75 of Set 10 | presidencia roque saenz pena
# Processing Record 77 of Set 10 | kirakira
# Processing Record 79 of Set 10 | muros
# Processing Record 81 of Set 10 | banyo
# Processing Record 83 of Set 10 | urdoma
# Processing Record 85 of Set 10 | ahuimanu
# Processing Record 87 of Set 10 | beisfjord
# Processing Record 89 of Set 10 | vidim
# Processing Record 91 of Set 10 | mana
# Processing Record 93 of Set 10 | crepy-en-valois
# Processing Record 95 of Set 10 | evensk
# Processing Record 97 of Set 10 | keighley
# Processing Record 99 of Set 10 | villamontes
# Processing Record 1 of Set 11 | tocopilla
# Processing Record 3 of Set 11 | alangalang
# Processing Record 5 of Set 11 | carutapera
# Processing Record 7 of Set 11 | anzio
# Processing Record 9 of Set 11 | esil
# Processing Record 11 of Set 11 | vangaindrano
# Processing Record 13 of Set 11 | faanui
# Processing Record 15 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 11 | mogadishu
# Processing Record 19 of Set 11 | bara
# Processing Record 21 of Set 11 | mapiripan
# Processing Record 23 of Set 11 | lima
# Processing Record 25 of Set 11 | juba
# Processing Record 27 of Set 11 | sindgi
# Processing Record 29 of Set 11 | cayenne
# Processing Record 31 of Set 11 | negara
# Processing Record 33 of Set 11 | wukari
# Processing Record 35 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 11 | karistos
# City not found. Skipping...
# Processing Record 39 of Set 11 | stornoway
# Processing Record 41 of Set 11 | iskateley
# Processing Record 43 of Set 11 | mackenzie
# Processing Record 45 of Set 11 | hohhot
# Processing Record 47 of Set 11 | havoysund
# Processing Record 49 of Set 11 | olga
# Processing Record 51 of Set 11 | mercedes
# Processing Record 53 of Set 11 | jingdezhen
# Processing Record 55 of Set 11 | ambon
# Processing Record 57 of Set 11 | kushima
# Processing Record 59 of Set 11 | ballina
# Processing Record 61 of Set 11 | batagay
# Processing Record 63 of Set 11 | laranjeiras do sul
# Processing Record 65 of Set 11 | vanimo
# Processing Record 67 of Set 11 | beringovskiy
# Processing Record 69 of Set 11 | atar
# Processing Record 71 of Set 11 | altukhovo
# Processing Record 73 of Set 11 | zhigansk
# Processing Record 75 of Set 11 | liku
# Processing Record 77 of Set 11 | solenzo
# Processing Record 79 of Set 11 | bobcaygeon
# Processing Record 81 of Set 11 | bukama
# Processing Record 83 of Set 11 | marabba
# Processing Record 85 of Set 11 | chubbuck
# Processing Record 87 of Set 11 | moanda
# Processing Record 89 of Set 11 | pesqueira
# Processing Record 91 of Set 11 | kudahuvadhoo
# Processing Record 93 of Set 11 | vieux-habitants
# Processing Record 95 of Set 11 | santa isabel do rio negro
# Processing Record 97 of Set 11 | miraflores
# Processing Record 99 of Set 11 | coquimbo
# Processing Record 1 of Set 12 | black diamond
# Processing Record 3 of Set 12 | barreirinhas
# Processing Record 5 of Set 12 | ojuelos de jalisco
# Processing Record 7 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 12 | cabedelo
# Processing Record 11 of Set 12 | kathmandu
# Processing Record 13 of Set 12 | kamen-rybolov
# Processing Record 15 of Set 12 | hudson bay
# Processing Record 17 of Set 12 | asau
# Processing Record 19 of Set 12 | auka
# Processing Record 21 of Set 12 | cienfuegos
# Processing Record 23 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 12 | kayiry
# Processing Record 27 of Set 12 | nacozari
# Processing Record 29 of Set 12 | terrace
# Processing Record 31 of Set 12 | mehamn
# Processing Record 33 of Set 12 | dawei
# Processing Record 35 of Set 12 | abapo
# Processing Record 37 of Set 12 | bikaner
# Processing Record 39 of Set 12 | umrala
# Processing Record 41 of Set 12 | long xuyen
# Processing Record 43 of Set 12 | beawar
# Processing Record 45 of Set 12 | lagoa
# Processing Record 47 of Set 12 | aykhal
# Processing Record 49 of Set 12 | jumla
# Processing Record 51 of Set 12 | puerto asis
# Processing Record 53 of Set 12 | manado
# Processing Record 55 of Set 12 | maturin
# Processing Record 57 of Set 12 | nishihara
# Processing Record 59 of Set 12 | portoferraio
# Processing Record 61 of Set 12 | mitsamiouli
# Processing Record 63 of Set 12 | humberto de campos
# Processing Record 65 of Set 12 | fairbanks
# Processing Record 67 of Set 12 | estelle
# Processing Record 69 of Set 12 | vityazevo
# Processing Record 71 of Set 12 | sao francisco do sul
# Processing Record 73 of Set 12 | gondanglegi
# Processing Record 75 of Set 12 | luganville
# Processing Record 77 of Set 12 | zagyvarekas
# Processing Record 79 of Set 12 | epe
# Processing Record 81 of Set 12 | maniitsoq
# Processing Record 83 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 85 of Set 12 | manaus
# Processing Record 87 of Set 12 | oktyabrskoye
# Processing Record 89 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 91 of Set 12 | mount isa
# Processing Record 93 of Set 12 | nacala
# Processing Record 95 of Set 12 | broome
# Processing Record 97 of Set 12 | shimoda
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng Current Description  Max Temp  \
# 0              Geraldton -28.7667  114.6000    scattered clouds     66.61
# 1                 Kodiak  57.7900 -152.4072           clear sky     17.11
# 2            New Norfolk -42.7826  147.0587    scattered clouds     51.93
# 3  Los Llanos De Aridane  28.6585  -17.9182    scattered clouds     64.13
# 4                Ushuaia -54.8000  -68.3000       broken clouds     51.46
# 5            Grand Gaube -20.0064   57.6608          light rain     78.39
# 6                  Bluff -46.6000  168.3333     overcast clouds     57.79
# 7              Busselton -33.6500  115.3333           clear sky     53.04
# 8              Grindavik  63.8424  -22.4338       broken clouds     39.67
# 9                Husavik  66.0449  -17.3389     overcast clouds     28.44
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        82          40       18.41      AU  2021-12-02 19:10:30
# 1        49           1       26.46      US  2021-12-02 19:09:39
# 2        72          37        1.99      AU  2021-12-02 19:10:30
# 3        63          40        3.00      ES  2021-12-02 19:10:31
# 4        62          75       14.97      AR  2021-12-02 19:09:19
# 5        75           8        5.01      MU  2021-12-02 19:10:31
# 6        95         100        3.24      NZ  2021-12-02 19:10:31
# 7        80           0       13.96      AU  2021-12-02 19:10:32
# 8        81          75       26.46      IS  2021-12-02 19:02:42
# 9        84         100       15.28      IS  2021-12-02 19:02:44

# %%
len(city_data_df)
# Out:
# 555

# %%
city_data_df_reordered = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[city_data_df_reordered]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Geraldton      AU -28.7667  114.6000     66.61        82
# 1                 Kodiak      US  57.7900 -152.4072     17.11        49
# 2            New Norfolk      AU -42.7826  147.0587     51.93        72
# 3  Los Llanos De Aridane      ES  28.6585  -17.9182     64.13        63
# 4                Ushuaia      AR -54.8000  -68.3000     51.46        62
# 5            Grand Gaube      MU -20.0064   57.6608     78.39        75
# 6                  Bluff      NZ -46.6000  168.3333     57.79        95
# 7              Busselton      AU -33.6500  115.3333     53.04        80
# 8              Grindavik      IS  63.8424  -22.4338     39.67        81
# 9                Husavik      IS  66.0449  -17.3389     28.44        84
#
#    Cloudiness  Wind Speed Current Description
# 0          40       18.41    scattered clouds
# 1           1       26.46           clear sky
# 2          37        1.99    scattered clouds
# 3          40        3.00    scattered clouds
# 4          75       14.97       broken clouds
# 5           8        5.01          light rain
# 6         100        3.24     overcast clouds
# 7           0       13.96           clear sky
# 8          75       26.46       broken clouds
# 9         100       15.28     overcast clouds

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("WeatherPy_DataBase.csv")
