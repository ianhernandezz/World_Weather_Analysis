# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Country": city_country,
                             "Date": city_date})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san andres
# Processing Record 3 of Set 1 | ostrovnoy
# Processing Record 5 of Set 1 | isangel
# Processing Record 7 of Set 1 | nalut
# Processing Record 9 of Set 1 | kidal
# Processing Record 11 of Set 1 | mataura
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 19 of Set 1 | busselton
# Processing Record 21 of Set 1 | lebu
# Processing Record 23 of Set 1 | jamestown
# Processing Record 25 of Set 1 | dresden
# Processing Record 27 of Set 1 | hilo
# Processing Record 29 of Set 1 | pimenteiras
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | vaini
# Processing Record 35 of Set 1 | barrow
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | hobart
# Processing Record 43 of Set 1 | kodinsk
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | lorengau
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 51 of Set 1 | castro
# Processing Record 53 of Set 1 | las margaritas
# Processing Record 55 of Set 1 | ode
# Processing Record 57 of Set 1 | tommot
# Processing Record 59 of Set 1 | saharsa
# Processing Record 61 of Set 1 | cape town
# Processing Record 63 of Set 1 | arraial do cabo
# Processing Record 65 of Set 1 | vestmannaeyjar
# Processing Record 67 of Set 1 | mahibadhoo
# Processing Record 69 of Set 1 | tiksi
# Processing Record 71 of Set 1 | sechura
# Processing Record 73 of Set 1 | raudeberg
# Processing Record 75 of Set 1 | avarua
# Processing Record 77 of Set 1 | saint-philippe
# Processing Record 79 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 81 of Set 1 | port moresby
# Processing Record 83 of Set 1 | albany
# Processing Record 85 of Set 1 | rikitea
# Processing Record 87 of Set 1 | yataity
# Processing Record 89 of Set 1 | kodiak
# Processing Record 91 of Set 1 | kapaa
# Processing Record 93 of Set 1 | ponta do sol
# Processing Record 95 of Set 1 | tasiilaq
# Processing Record 97 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 99 of Set 1 | filadelfia
# Processing Record 1 of Set 2 | bayji
# Processing Record 3 of Set 2 | coquimbo
# Processing Record 5 of Set 2 | miastko
# Processing Record 7 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | namibe
# Processing Record 11 of Set 2 | yulara
# Processing Record 13 of Set 2 | marang
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | koumra
# Processing Record 19 of Set 2 | la grande
# Processing Record 21 of Set 2 | atuona
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | hermanus
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | maumere
# Processing Record 31 of Set 2 | mount pleasant
# Processing Record 33 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 35 of Set 2 | fort nelson
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 2 | nakasongola
# Processing Record 41 of Set 2 | qandala
# Processing Record 43 of Set 2 | vestmanna
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | mount gambier
# Processing Record 51 of Set 2 | lavrentiya
# Processing Record 53 of Set 2 | wajid
# Processing Record 55 of Set 2 | port alfred
# Processing Record 57 of Set 2 | pevek
# Processing Record 59 of Set 2 | thompson
# Processing Record 61 of Set 2 | marsa matruh
# Processing Record 63 of Set 2 | vardo
# Processing Record 65 of Set 2 | bethel
# Processing Record 67 of Set 2 | butaritari
# Processing Record 69 of Set 2 | lons-le-saunier
# Processing Record 71 of Set 2 | general roca
# Processing Record 73 of Set 2 | saint george
# Processing Record 75 of Set 2 | sevsk
# Processing Record 77 of Set 2 | sao filipe
# Processing Record 79 of Set 2 | caravelas
# Processing Record 81 of Set 2 | ilulissat
# Processing Record 83 of Set 2 | sept-iles
# Processing Record 85 of Set 2 | torbay
# Processing Record 87 of Set 2 | tuktoyaktuk
# Processing Record 89 of Set 2 | smithers
# Processing Record 91 of Set 2 | grande prairie
# Processing Record 93 of Set 2 | ovalle
# Processing Record 95 of Set 2 | fuglebjerg
# Processing Record 97 of Set 2 | airai
# Processing Record 99 of Set 2 | chuy
# Processing Record 1 of Set 3 | salalah
# Processing Record 3 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | tateyama
# Processing Record 7 of Set 3 | dauriya
# Processing Record 9 of Set 3 | sioux lookout
# Processing Record 11 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | rawson
# Processing Record 15 of Set 3 | najran
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | ryotsu
# Processing Record 23 of Set 3 | waipawa
# Processing Record 25 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 29 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | oistins
# Processing Record 33 of Set 3 | la chapelle-sur-erdre
# Processing Record 35 of Set 3 | east london
# Processing Record 37 of Set 3 | krasnoselkup
# Processing Record 39 of Set 3 | parras
# City not found. Skipping...
# Processing Record 41 of Set 3 | bluff
# Processing Record 43 of Set 3 | albertville
# Processing Record 45 of Set 3 | port-cartier
# Processing Record 47 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 3 | bani walid
# Processing Record 51 of Set 3 | lagoa
# Processing Record 53 of Set 3 | otradnoye
# Processing Record 55 of Set 3 | dong hoi
# Processing Record 57 of Set 3 | georgetown
# Processing Record 59 of Set 3 | iqaluit
# Processing Record 61 of Set 3 | dingle
# Processing Record 63 of Set 3 | pandan
# Processing Record 65 of Set 3 | olafsvik
# Processing Record 67 of Set 3 | zhezkazgan
# Processing Record 69 of Set 3 | vangaindrano
# Processing Record 71 of Set 3 | lompoc
# Processing Record 73 of Set 3 | khatanga
# Processing Record 75 of Set 3 | upernavik
# Processing Record 77 of Set 3 | bubaque
# Processing Record 79 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 81 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 83 of Set 3 | barcelos
# Processing Record 85 of Set 3 | lewiston
# Processing Record 87 of Set 3 | praia
# Processing Record 89 of Set 3 | provideniya
# Processing Record 91 of Set 3 | bolton
# Processing Record 93 of Set 3 | madang
# Processing Record 95 of Set 3 | vila do maio
# Processing Record 97 of Set 3 | yellowknife
# Processing Record 99 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | skibbereen
# Processing Record 3 of Set 4 | panjab
# Processing Record 5 of Set 4 | koboko
# Processing Record 7 of Set 4 | saldanha
# Processing Record 9 of Set 4 | osecina
# Processing Record 11 of Set 4 | iberia
# Processing Record 13 of Set 4 | sao joao da barra
# Processing Record 15 of Set 4 | algiers
# Processing Record 17 of Set 4 | mar del plata
# Processing Record 19 of Set 4 | mayo
# Processing Record 21 of Set 4 | aasiaat
# Processing Record 23 of Set 4 | atyrau
# Processing Record 25 of Set 4 | korla
# Processing Record 27 of Set 4 | sur
# Processing Record 29 of Set 4 | rio grande
# Processing Record 31 of Set 4 | cayenne
# Processing Record 33 of Set 4 | cockburn town
# Processing Record 35 of Set 4 | deep river
# Processing Record 37 of Set 4 | san quintin
# Processing Record 39 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 4 | santa maria
# Processing Record 43 of Set 4 | barra do corda
# Processing Record 45 of Set 4 | wanxian
# Processing Record 47 of Set 4 | hirara
# Processing Record 49 of Set 4 | half moon bay
# Processing Record 51 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 53 of Set 4 | pisco
# Processing Record 55 of Set 4 | bulungu
# Processing Record 57 of Set 4 | storforshei
# Processing Record 59 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 61 of Set 4 | durban
# Processing Record 63 of Set 4 | hithadhoo
# Processing Record 65 of Set 4 | chimbote
# Processing Record 67 of Set 4 | biak
# Processing Record 69 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 71 of Set 4 | gamba
# Processing Record 73 of Set 4 | camana
# Processing Record 75 of Set 4 | henties bay
# Processing Record 77 of Set 4 | iida
# Processing Record 79 of Set 4 | sorland
# Processing Record 81 of Set 4 | ayan
# Processing Record 83 of Set 4 | sinazongwe
# Processing Record 85 of Set 4 | sisimiut
# Processing Record 87 of Set 4 | flin flon
# Processing Record 89 of Set 4 | pareora
# Processing Record 91 of Set 4 | at-bashi
# Processing Record 93 of Set 4 | severo-yeniseyskiy
# Processing Record 95 of Set 4 | vaitape
# Processing Record 97 of Set 4 | teya
# Processing Record 99 of Set 4 | chara
# Processing Record 1 of Set 5 | kloulklubed
# Processing Record 3 of Set 5 | port hardy
# Processing Record 5 of Set 5 | deputatskiy
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 5 | maltahohe
# Processing Record 11 of Set 5 | saint quentin
# City not found. Skipping...
# Processing Record 13 of Set 5 | belaya kholunitsa
# Processing Record 15 of Set 5 | karratha
# Processing Record 17 of Set 5 | japura
# Processing Record 19 of Set 5 | matara
# Processing Record 21 of Set 5 | narsaq
# Processing Record 23 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 25 of Set 5 | dayong
# Processing Record 27 of Set 5 | dikson
# Processing Record 29 of Set 5 | aksu
# Processing Record 31 of Set 5 | bucerias
# Processing Record 33 of Set 5 | qaanaaq
# Processing Record 35 of Set 5 | cabedelo
# Processing Record 37 of Set 5 | kogon
# Processing Record 39 of Set 5 | geraldton
# Processing Record 41 of Set 5 | tuatapere
# Processing Record 43 of Set 5 | avera
# Processing Record 45 of Set 5 | victoria
# Processing Record 47 of Set 5 | cairo
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 51 of Set 5 | goderich
# Processing Record 53 of Set 5 | maxixe
# Processing Record 55 of Set 5 | koeru
# Processing Record 57 of Set 5 | maamba
# Processing Record 59 of Set 5 | komsomolskiy
# Processing Record 61 of Set 5 | galle
# Processing Record 63 of Set 5 | manokwari
# Processing Record 65 of Set 5 | cidreira
# Processing Record 67 of Set 5 | sola
# Processing Record 69 of Set 5 | sitka
# Processing Record 71 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 73 of Set 5 | san patricio
# Processing Record 75 of Set 5 | los llanos de aridane
# Processing Record 77 of Set 5 | grand gaube
# Processing Record 79 of Set 5 | saint-georges
# Processing Record 81 of Set 5 | changli
# Processing Record 83 of Set 5 | veraval
# Processing Record 85 of Set 5 | antofagasta
# Processing Record 87 of Set 5 | comodoro rivadavia
# Processing Record 89 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 91 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 93 of Set 5 | camacha
# Processing Record 95 of Set 5 | mehamn
# Processing Record 97 of Set 5 | jalu
# Processing Record 99 of Set 5 | muravlenko
# Processing Record 1 of Set 6 | codrington
# Processing Record 3 of Set 6 | katherine
# Processing Record 5 of Set 6 | sao miguel do araguaia
# Processing Record 7 of Set 6 | katsuura
# Processing Record 9 of Set 6 | seoul
# Processing Record 11 of Set 6 | souillac
# Processing Record 13 of Set 6 | bestobe
# Processing Record 15 of Set 6 | las cruces
# Processing Record 17 of Set 6 | podor
# Processing Record 19 of Set 6 | wanlaweyn
# Processing Record 21 of Set 6 | omsukchan
# Processing Record 23 of Set 6 | mahanje
# Processing Record 25 of Set 6 | tra vinh
# Processing Record 27 of Set 6 | naryan-mar
# Processing Record 29 of Set 6 | vilyuysk
# Processing Record 31 of Set 6 | eskisehir
# Processing Record 33 of Set 6 | bathsheba
# Processing Record 35 of Set 6 | kavieng
# Processing Record 37 of Set 6 | orlik
# Processing Record 39 of Set 6 | micheweni
# Processing Record 41 of Set 6 | turukhansk
# Processing Record 43 of Set 6 | gairatganj
# Processing Record 45 of Set 6 | westport
# Processing Record 47 of Set 6 | leningradskiy
# Processing Record 49 of Set 6 | petauke
# Processing Record 51 of Set 6 | oktyabrskiy
# Processing Record 53 of Set 6 | constitucion
# Processing Record 55 of Set 6 | hovd
# Processing Record 57 of Set 6 | guerrero negro
# Processing Record 59 of Set 6 | tabatinga
# Processing Record 61 of Set 6 | dunedin
# Processing Record 63 of Set 6 | manjakandriana
# Processing Record 65 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 67 of Set 6 | powell river
# Processing Record 69 of Set 6 | bayan
# Processing Record 71 of Set 6 | atikokan
# Processing Record 73 of Set 6 | banda aceh
# Processing Record 75 of Set 6 | juegang
# Processing Record 77 of Set 6 | yenagoa
# Processing Record 79 of Set 6 | leh
# Processing Record 81 of Set 6 | yatou
# Processing Record 83 of Set 6 | zhanaozen
# Processing Record 85 of Set 6 | hobyo
# Processing Record 87 of Set 6 | taoudenni
# Processing Record 89 of Set 6 | broken hill
# Processing Record 91 of Set 6 | fairbanks
# Processing Record 93 of Set 6 | port lincoln
# Processing Record 95 of Set 6 | watertown
# Processing Record 97 of Set 6 | zemio
# Processing Record 99 of Set 6 | mattru
# Processing Record 1 of Set 7 | tabou
# Processing Record 3 of Set 7 | williams lake
# Processing Record 5 of Set 7 | mandiana
# Processing Record 7 of Set 7 | nemuro
# Processing Record 9 of Set 7 | tarakan
# Processing Record 11 of Set 7 | atmakur
# Processing Record 13 of Set 7 | yining
# Processing Record 15 of Set 7 | venice
# Processing Record 17 of Set 7 | surt
# Processing Record 19 of Set 7 | la ronge
# Processing Record 21 of Set 7 | netrakona
# Processing Record 23 of Set 7 | zaraza
# Processing Record 25 of Set 7 | san ignacio
# Processing Record 27 of Set 7 | pozo colorado
# Processing Record 29 of Set 7 | metsovon
# City not found. Skipping...
# Processing Record 31 of Set 7 | touros
# Processing Record 33 of Set 7 | nantucket
# Processing Record 35 of Set 7 | tingo maria
# Processing Record 37 of Set 7 | qasigiannguit
# Processing Record 39 of Set 7 | beloomut
# Processing Record 41 of Set 7 | opuwo
# Processing Record 43 of Set 7 | kirakira
# Processing Record 45 of Set 7 | marzuq
# Processing Record 47 of Set 7 | talnakh
# Processing Record 49 of Set 7 | gorin
# Processing Record 51 of Set 7 | nara
# Processing Record 53 of Set 7 | laguna
# Processing Record 55 of Set 7 | saskylakh
# Processing Record 57 of Set 7 | shadegan
# Processing Record 59 of Set 7 | scottsbluff
# Processing Record 61 of Set 7 | coos bay
# Processing Record 63 of Set 7 | te anau
# Processing Record 65 of Set 7 | basco
# Processing Record 67 of Set 7 | orcopampa
# Processing Record 69 of Set 7 | tautira
# Processing Record 71 of Set 7 | statesboro
# Processing Record 73 of Set 7 | broome
# Processing Record 75 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 77 of Set 7 | pangnirtung
# Processing Record 79 of Set 7 | bambanglipuro
# Processing Record 81 of Set 7 | valera
# Processing Record 83 of Set 7 | itarema
# Processing Record 85 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 87 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 89 of Set 7 | viedma
# Processing Record 91 of Set 7 | harper
# Processing Record 93 of Set 7 | payakumbuh
# Processing Record 95 of Set 7 | ponta delgada
# Processing Record 97 of Set 7 | abha
# Processing Record 99 of Set 7 | aloleng
# Processing Record 1 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 3 of Set 8 | mount isa
# Processing Record 5 of Set 8 | saint-joseph
# Processing Record 7 of Set 8 | faya
# Processing Record 9 of Set 8 | barra do garcas
# Processing Record 11 of Set 8 | aklavik
# Processing Record 13 of Set 8 | ocamonte
# Processing Record 15 of Set 8 | bud
# Processing Record 17 of Set 8 | marsh harbour
# Processing Record 19 of Set 8 | balkanabat
# Processing Record 21 of Set 8 | teguldet
# Processing Record 23 of Set 8 | kahului
# Processing Record 25 of Set 8 | jinxiang
# Processing Record 27 of Set 8 | peravurani
# Processing Record 29 of Set 8 | hambantota
# Processing Record 31 of Set 8 | majalengka
# Processing Record 33 of Set 8 | trairi
# Processing Record 35 of Set 8 | bardiyah
# Processing Record 37 of Set 8 | fougamou
# Processing Record 39 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 41 of Set 8 | freeport
# Processing Record 43 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 8 | abalak
# Processing Record 47 of Set 8 | meulaboh
# Processing Record 49 of Set 8 | fukuma
# Processing Record 51 of Set 8 | gbarnga
# Processing Record 53 of Set 8 | kaitangata
# Processing Record 55 of Set 8 | puerto baquerizo moreno
# Processing Record 57 of Set 8 | cairns
# Processing Record 59 of Set 8 | acapulco
# Processing Record 61 of Set 8 | xichang
# Processing Record 63 of Set 8 | okha
# Processing Record 65 of Set 8 | buchanan
# Processing Record 67 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 69 of Set 8 | pangoa
# Processing Record 71 of Set 8 | nautla
# Processing Record 73 of Set 8 | isiro
# Processing Record 75 of Set 8 | port hedland
# Processing Record 77 of Set 8 | hofu
# Processing Record 79 of Set 8 | pedernales
# Processing Record 81 of Set 8 | vila velha
# Processing Record 83 of Set 8 | srednekolymsk
# Processing Record 85 of Set 8 | qui nhon
# Processing Record 87 of Set 8 | kapoeta
# Processing Record 89 of Set 8 | yar-sale
# Processing Record 91 of Set 8 | korgen
# Processing Record 93 of Set 8 | lujan
# Processing Record 95 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 97 of Set 8 | eyl
# Processing Record 99 of Set 8 | talara
# Processing Record 1 of Set 9 | biritiba-mirim
# Processing Record 3 of Set 9 | kutum
# Processing Record 5 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 7 of Set 9 | yarmouth
# Processing Record 9 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 9 | halifax
# Processing Record 13 of Set 9 | rundu
# Processing Record 15 of Set 9 | kyren
# Processing Record 17 of Set 9 | lazaro cardenas
# Processing Record 19 of Set 9 | kjollefjord
# Processing Record 21 of Set 9 | guanambi
# Processing Record 23 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 9 | cap malheureux
# Processing Record 27 of Set 9 | coihaique
# Processing Record 29 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 31 of Set 9 | oromocto
# Processing Record 33 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 9 | naze
# Processing Record 37 of Set 9 | roela
# Processing Record 39 of Set 9 | turbat
# Processing Record 41 of Set 9 | carutapera
# Processing Record 43 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 9 | salinopolis
# Processing Record 47 of Set 9 | san fernando
# Processing Record 49 of Set 9 | ossora
# Processing Record 51 of Set 9 | pavlivka
# Processing Record 53 of Set 9 | aitape
# Processing Record 55 of Set 9 | san cristobal
# Processing Record 57 of Set 9 | ucluelet
# Processing Record 59 of Set 9 | college
# Processing Record 61 of Set 9 | sehore
# Processing Record 63 of Set 9 | shingu
# Processing Record 65 of Set 9 | margate
# Processing Record 67 of Set 9 | sterling
# Processing Record 69 of Set 9 | flinders
# Processing Record 71 of Set 9 | kamenka
# Processing Record 73 of Set 9 | honiara
# Processing Record 75 of Set 9 | obuasi
# Processing Record 77 of Set 9 | great falls
# Processing Record 79 of Set 9 | dudinka
# Processing Record 81 of Set 9 | conde
# Processing Record 83 of Set 9 | high rock
# Processing Record 85 of Set 9 | faanui
# Processing Record 87 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 89 of Set 9 | tilichiki
# Processing Record 91 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 93 of Set 9 | rockingham
# Processing Record 95 of Set 9 | takoradi
# Processing Record 97 of Set 9 | vao
# Processing Record 99 of Set 9 | bonavista
# Processing Record 1 of Set 10 | loikaw
# Processing Record 3 of Set 10 | jiwani
# Processing Record 5 of Set 10 | daultala
# Processing Record 7 of Set 10 | terney
# Processing Record 9 of Set 10 | addi ugri
# City not found. Skipping...
# Processing Record 11 of Set 10 | matagami
# Processing Record 13 of Set 10 | payson
# Processing Record 15 of Set 10 | arman
# Processing Record 17 of Set 10 | makakilo city
# Processing Record 19 of Set 10 | grindavik
# Processing Record 21 of Set 10 | poum
# Processing Record 23 of Set 10 | ulaangom
# Processing Record 25 of Set 10 | vargashi
# Processing Record 27 of Set 10 | mbini
# Processing Record 29 of Set 10 | ko samui
# Processing Record 31 of Set 10 | lipin bor
# Processing Record 33 of Set 10 | namatanai
# Processing Record 35 of Set 10 | roebourne
# Processing Record 37 of Set 10 | kalmunai
# Processing Record 39 of Set 10 | vostok
# Processing Record 41 of Set 10 | ixtapa
# Processing Record 43 of Set 10 | seymchan
# Processing Record 45 of Set 10 | voh
# Processing Record 47 of Set 10 | douglas
# Processing Record 49 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 51 of Set 10 | ahipara
# Processing Record 53 of Set 10 | palasa
# Processing Record 55 of Set 10 | taltal
# Processing Record 57 of Set 10 | valparaiso
# Processing Record 59 of Set 10 | porto walter
# Processing Record 61 of Set 10 | shelburne
# Processing Record 63 of Set 10 | domoni
# Processing Record 65 of Set 10 | bad soden-salmunster
# Processing Record 67 of Set 10 | hofn
# Processing Record 69 of Set 10 | sholapur
# Processing Record 71 of Set 10 | ferrol
# Processing Record 73 of Set 10 | barrhead
# Processing Record 75 of Set 10 | goundam
# Processing Record 77 of Set 10 | road town
# Processing Record 79 of Set 10 | lipari
# Processing Record 81 of Set 10 | lovozero
# Processing Record 83 of Set 10 | gravenhurst
# Processing Record 85 of Set 10 | esperance
# Processing Record 87 of Set 10 | nouadhibou
# Processing Record 89 of Set 10 | kaoma
# Processing Record 91 of Set 10 | kasempa
# Processing Record 93 of Set 10 | bentonville
# Processing Record 95 of Set 10 | yangambi
# Processing Record 97 of Set 10 | saint-ambroise
# Processing Record 99 of Set 10 | roma
# Processing Record 1 of Set 11 | austin
# Processing Record 3 of Set 11 | takanosu
# Processing Record 5 of Set 11 | asau
# Processing Record 7 of Set 11 | karla
# Processing Record 9 of Set 11 | punta alta
# Processing Record 11 of Set 11 | longyearbyen
# Processing Record 13 of Set 11 | mosquera
# Processing Record 15 of Set 11 | galveston
# Processing Record 17 of Set 11 | ojinaga
# Processing Record 19 of Set 11 | alamosa
# Processing Record 21 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 11 | lerik
# Processing Record 25 of Set 11 | havre-saint-pierre
# Processing Record 27 of Set 11 | verkhnevilyuysk
# Processing Record 29 of Set 11 | adrar
# Processing Record 31 of Set 11 | cangzhou
# Processing Record 33 of Set 11 | neiafu
# Processing Record 35 of Set 11 | smirnykh
# Processing Record 37 of Set 11 | kiruna
# Processing Record 39 of Set 11 | vila franca do campo
# Processing Record 41 of Set 11 | podgornoye
# Processing Record 43 of Set 11 | mutoko
# Processing Record 45 of Set 11 | mayumba
# Processing Record 47 of Set 11 | clyde river
# Processing Record 49 of Set 11 | manggar
# Processing Record 51 of Set 11 | saint-pierre
# Processing Record 53 of Set 11 | mozarlandia
# Processing Record 55 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 57 of Set 11 | norman wells
# Processing Record 59 of Set 11 | topchanchi
# Processing Record 61 of Set 11 | ome
# Processing Record 63 of Set 11 | anadyr
# Processing Record 65 of Set 11 | sindand
# City not found. Skipping...
# Processing Record 67 of Set 11 | bossangoa
# Processing Record 69 of Set 11 | bayevo
# Processing Record 71 of Set 11 | craig
# Processing Record 73 of Set 11 | jiuquan
# Processing Record 75 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 77 of Set 11 | hami
# Processing Record 79 of Set 11 | chapais
# Processing Record 81 of Set 11 | kalmar
# Processing Record 83 of Set 11 | san rafael
# Processing Record 85 of Set 11 | kheri
# Processing Record 87 of Set 11 | san remigio
# Processing Record 89 of Set 11 | luang prabang
# Processing Record 91 of Set 11 | grenville
# Processing Record 93 of Set 11 | russell
# Processing Record 95 of Set 11 | bac lieu
# Processing Record 97 of Set 11 | cornwall
# Processing Record 99 of Set 11 | haikou
# Processing Record 1 of Set 12 | lancaster
# Processing Record 3 of Set 12 | oreanda
# City not found. Skipping...
# Processing Record 5 of Set 12 | husavik
# Processing Record 7 of Set 12 | baglung
# Processing Record 9 of Set 12 | kelvington
# Processing Record 11 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 12 | kargopol
# Processing Record 15 of Set 12 | del rio
# Processing Record 17 of Set 12 | shakawe
# Processing Record 19 of Set 12 | hervey bay
# Processing Record 21 of Set 12 | falmouth
# Processing Record 23 of Set 12 | high level
# Processing Record 25 of Set 12 | kemise
# Processing Record 27 of Set 12 | zyryanka
# Processing Record 29 of Set 12 | linhares
# Processing Record 31 of Set 12 | luderitz
# Processing Record 33 of Set 12 | envira
# Processing Record 35 of Set 12 | kupang
# Processing Record 37 of Set 12 | caxias
# Processing Record 39 of Set 12 | yate
# Processing Record 41 of Set 12 | nizhniy tsasuchey
# Processing Record 43 of Set 12 | gilbues
# Processing Record 45 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 12 | gat
# Processing Record 49 of Set 12 | samarai
# Processing Record 51 of Set 12 | papara
# Processing Record 53 of Set 12 | macas
# Processing Record 55 of Set 12 | toora-khem
# Processing Record 57 of Set 12 | sobolevo
# Processing Record 59 of Set 12 | itoman
# Processing Record 61 of Set 12 | saint-augustin
# Processing Record 63 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 65 of Set 12 | karamken
# City not found. Skipping...
# Processing Record 67 of Set 12 | saint-francois
# Processing Record 69 of Set 12 | ambon
# Processing Record 71 of Set 12 | maneadero
# Processing Record 73 of Set 12 | corrente
# Processing Record 75 of Set 12 | novochernorechenskiy
# Processing Record 77 of Set 12 | baiyin
# Processing Record 79 of Set 12 | verkhnyaya inta
# Processing Record 81 of Set 12 | alta floresta
# Processing Record 83 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 85 of Set 12 | wattegama
# Processing Record 87 of Set 12 | fortuna
# Processing Record 89 of Set 12 | tikapur
# Processing Record 91 of Set 12 | khani
# Processing Record 93 of Set 12 | bacabal
# Processing Record 95 of Set 12 | batemans bay
# Processing Record 97 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 99 of Set 12 | callaguip
# Processing Record 1 of Set 13 | marawi
# Processing Record 3 of Set 13 | ballina
# Processing Record 5 of Set 13 | padang
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 552

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      San Andres  12.5847  -81.7006     81.81        76          43
# 1       Ostrovnoy  68.0531   39.5131     25.36        62         100
# 2         Isangel -19.5500  169.2667     87.91        70          75
# 3           Nalut  30.3333   10.8500     48.70        56           4
# 4           Kidal  18.4411    1.4078     73.87        14          51
# 5         Mataura -46.1927  168.8643     68.49        53          48
# 6  Port Elizabeth -33.9180   25.5701     63.10        87          75
# 7     New Norfolk -42.7826  147.0587     89.65        27         100
# 8        Cherskiy  68.7500  161.3000    -15.66        98         100
# 9       Busselton -33.6500  115.3333     65.08        51         100
#
#    Wind Speed Country                 Date
# 0       19.84      CO  2021-12-01 02:01:25
# 1       36.26      RU  2021-12-01 01:57:08
# 2        6.91      VU  2021-12-01 01:57:08
# 3        8.72      LY  2021-12-01 01:57:08
# 4       10.65      ML  2021-12-01 02:03:21
# 5        5.70      NZ  2021-12-01 02:03:01
# 6        2.80      ZA  2021-12-01 02:00:15
# 7        1.99      AU  2021-12-01 02:03:22
# 8        5.73      RU  2021-12-01 02:03:22
# 9        7.58      AU  2021-12-01 02:03:22

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("data/WeatherPy_challenge.csv", index_label="City ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-8d18615e0093> in <module>
#       1 #Export the dataframe to csv file.
# ----> 2 city_data_df.to_csv("data/WeatherPy_challenge.csv", index_label="City ID")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/WeatherPy_challenge.csv'
